# %%
import pandas as pd
import pandasql as ps

# %%
category = pd.read_csv('data/category_data.csv')
orders = pd.read_csv('data/order_data.csv')
order_items = pd.read_csv('data/order_items_data.csv')
products = pd.read_csv('data/product_data.csv')
reviews = pd.read_csv('data/review_data.csv')
users = pd.read_csv('data/user_data.csv')

# %%
t1_p1 = '''
SELECT 
    product_id, product_name, description, price, category_id
FROM 
    products
WHERE 
    category_id = (
        SELECT category_id FROM category WHERE category_name LIKE 'Sports%'
    )
'''
ps.sqldf(t1_p1, locals())
# Out:
#    product_id   product_name  \
# 0          15  Mountain Bike
# 1          16  Tennis Racket
#
#                                          description   price  category_id
# 0  Conquer the trails with this high-performance ...  1000.0            8
# 1  Take your tennis game to the next level with t...    54.0            8

# %%
# orders.groupby('user_id').agg({'order_id': 'count'}).reset_index().rename(columns={'order_id': 'order_count'})
t1_p2 = '''
SELECT u.user_id, u.username, o.total_orders
FROM
(
    (
        SELECT user_id, username
        FROM users
    ) u
    INNER JOIN
    (
        SELECT user_id, COUNT(order_id) AS total_orders
        FROM orders
        GROUP BY user_id
    ) o
    ON u.user_id = o.user_id
)
'''
ps.sqldf(t1_p2, locals())
# Out:
#     user_id          username  total_orders
# 0         1           johndoe             1
# 1         2         janesmith             1
# 2         3         maryjones             1
# 3         4       robertbrown             1
# 4         5       sarahwilson             1
# 5         6        michaellee             1
# 6         7      lisawilliams             1
# 7         8       chrisharris             1
# 8         9     emilythompson             1
# 9        10     davidmartinez             1
# 10       11     amandajohnson             1
# 11       12    jasonrodriguez             1
# 12       13      ashleytaylor             1
# 13       14     matthewthomas             1
# 14       15      sophiawalker             1
# 15       16     jacobanderson             1
# 16       17       olivialopez             1
# 17       18       ethanmiller             1
# 18       19     emilygonzalez             1
# 19       20  williamhernandez             1
# 20       21      sophiawright             1
# 21       22     alexanderhill             1
# 22       23      madisonmoore             1
# 23       24       jamesrogers             1
# 24       25         emilyward             1
# 25       26    benjamincarter             1
# 26       27      gracestewart             1
# 27       28      danielturner             1
# 28       29      elliecollins             1
# 29       30       williamwood             1

# %%
# rr = reviews.groupby('product_id').agg({'rating': 'mean'}).reset_index().rename(columns={'rating': 'avg_rating'})
# products.merge(rr, how='right', on='product_id', suffixes=('', '_r'))

t1_p3 = '''
SELECT r.product_id, p.product_name, r.avg_rating
FROM
(
    (
        SELECT product_id, product_name
        FROM products
    ) p
    RIGHT JOIN
    (
        SELECT product_id, AVG(rating) AS avg_rating
        FROM reviews
        GROUP BY product_id
    ) r
    ON p.product_id = r.product_id
)
ORDER BY avg_rating DESC
'''
ps.sqldf(t1_p3, locals())
# Out:
#     product_id           product_name  avg_rating
# 0            1           Smartphone X         5.0
# 1            4               Smart TV         5.0
# 2            7           Coffee Maker         5.0
# 3           11               Yoga Mat         5.0
# 4           15          Mountain Bike         5.0
# 5           18                   None         5.0
# 6           21                   None         5.0
# 7           25                   None         5.0
# 8           29                   None         5.0
# 9            2    Wireless Headphones         4.0
# 10           6         Designer Dress         4.0
# 11           9          Action Camera         4.0
# 12          12           Skincare Set         4.0
# 13          16          Tennis Racket         4.0
# 14          20                   None         4.0
# 15          23                   None         4.0
# 16          26                   None         4.0
# 17          30                   None         4.0
# 18           3             Laptop Pro         3.0
# 19           8           Toaster Oven         3.0
# 20          14       Weighted Blanket         3.0
# 21          17                   None         3.0
# 22          22                   None         3.0
# 23          28                   None         3.0
# 24           5          Running Shoes         2.0
# 25          13   Vitamin C Supplement         2.0
# 26          19                   None         2.0
# 27          27                   None         2.0
# 28          10  Board Game Collection         1.0
# 29          24                   None         1.0

# %%
# orders.groupby('user_id').agg({'total_amount': 'sum'}).reset_index().rename(columns={'total_amount': 'total_spent_amount'}).sort_values('total_spent_amount', ascending=False)
t1_p4 = '''
SELECT o.user_id, u.username, o.total_amount_spent
FROM
(
    (
        SELECT user_id, username
        FROM users
    ) u
    RIGHT JOIN
    (
        SELECT user_id, SUM(total_amount) AS total_amount_spent
        FROM orders
        GROUP BY user_id
    ) o
    ON u.user_id = o.user_id
)
ORDER BY o.total_amount_spent DESC
LIMIT 5
'''
ps.sqldf(t1_p4, locals())
# Out:
#    user_id        username  total_amount_spent
# 0       12  jasonrodriguez               160.0
# 1        4     robertbrown               155.0
# 2        8     chrisharris               150.0
# 3       24     jamesrogers               150.0
# 4       17     olivialopez               145.0

# %%
t2_p5 = '''
SELECT 
  r.product_id, p.product_name, AVG(r.rating) AS average_rating
FROM 
  products p
RIGHT JOIN 
  reviews r 
ON 
  p.product_id = r.product_id
GROUP BY 
  r.product_id
HAVING AVG(r.rating) = (
  SELECT 
    MAX(avg_rating)
  FROM (
    SELECT 
      AVG(rating) AS avg_rating
    FROM 
      reviews
    GROUP BY 
      product_id
  )
)
'''
ps.sqldf(t2_p5, locals())
# Out:
#    product_id   product_name  average_rating
# 0           1   Smartphone X             5.0
# 1           4       Smart TV             5.0
# 2           7   Coffee Maker             5.0
# 3          11       Yoga Mat             5.0
# 4          15  Mountain Bike             5.0
# 5          18           None             5.0
# 6          21           None             5.0
# 7          25           None             5.0
# 8          29           None             5.0

# %%
users.merge(orders, how='inner', on='user_id').merge(order_items, how='inner', on='order_id').merge(products, how='left', on='product_id').merge(category, how='left', on='category_id')
# Out:
#     user_id        username                       email password  \
# 0         1         johndoe         johndoe@example.com  pass123
# 1         1         johndoe         johndoe@example.com  pass123
# 2         2       janesmith       janesmith@example.com  pass456
# 3         2       janesmith       janesmith@example.com  pass456
# 4         3       maryjones       maryjones@example.com  pass789
# 5         3       maryjones       maryjones@example.com  pass789
# 6         4     robertbrown     robertbrown@example.com  passabc
# 7         4     robertbrown     robertbrown@example.com  passabc
# 8         5     sarahwilson     sarahwilson@example.com  passxyz
# 9         5     sarahwilson     sarahwilson@example.com  passxyz
# 10        6      michaellee      michaellee@example.com  pass456
# 11        6      michaellee      michaellee@example.com  pass456
# 12        7    lisawilliams    lisawilliams@example.com  pass789
# 13        7    lisawilliams    lisawilliams@example.com  pass789
# 14        8     chrisharris     chrisharris@example.com  pass123
# 15        8     chrisharris     chrisharris@example.com  pass123
# 16        9   emilythompson   emilythompson@example.com  passabc
# 17        9   emilythompson   emilythompson@example.com  passabc
# 18       10   davidmartinez   davidmartinez@example.com  passxyz
# 19       10   davidmartinez   davidmartinez@example.com  passxyz
# 20       11   amandajohnson   amandajohnson@example.com  pass123
# 21       11   amandajohnson   amandajohnson@example.com  pass123
# 22       12  jasonrodriguez  jasonrodriguez@example.com  pass456
# 23       12  jasonrodriguez  jasonrodriguez@example.com  pass456
# 24       13    ashleytaylor    ashleytaylor@example.com  pass789
# 25       13    ashleytaylor    ashleytaylor@example.com  pass789
# 26       14   matthewthomas   matthewthomas@example.com  passabc
# 27       14   matthewthomas   matthewthomas@example.com  passabc
# 28       15    sophiawalker    sophiawalker@example.com  pass123
# 29       15    sophiawalker    sophiawalker@example.com  pass123
#
#           address  phone_number  order_id  order_date  total_amount  \
# 0     123 Main St  123-456-7890         1  2021-01-05         100.0
# 1     123 Main St  123-456-7890         1  2021-01-05         100.0
# 2      456 Elm St  987-654-3210         2  2021-02-10          75.0
# 3      456 Elm St  987-654-3210         2  2021-02-10          75.0
# 4      789 Oak St  555-123-4567         3  2021-03-15         120.0
# 5      789 Oak St  555-123-4567         3  2021-03-15         120.0
# 6     321 Pine St  111-222-3333         4  2021-04-20         155.0
# 7     321 Pine St  111-222-3333         4  2021-04-20         155.0
# 8    567 Maple St  444-555-6666         5  2021-05-25          90.0
# 9    567 Maple St  444-555-6666         5  2021-05-25          90.0
# 10   890 Cedar St  777-888-9999         6  2021-06-30          80.0
# 11   890 Cedar St  777-888-9999         6  2021-06-30          80.0
# 12   432 Birch St  222-333-4444         7  2021-07-05         125.0
# 13   432 Birch St  222-333-4444         7  2021-07-05         125.0
# 14  876 Walnut St  666-777-8888         8  2021-08-10         150.0
# 15  876 Walnut St  666-777-8888         8  2021-08-10         150.0
# 16     543 Oak St  999-000-1111         9  2021-09-15          95.0
# 17     543 Oak St  999-000-1111         9  2021-09-15          95.0
# 18     987 Elm St  333-444-5555        10  2021-10-20          70.0
# 19     987 Elm St  333-444-5555        10  2021-10-20          70.0
# 20    654 Pine St  888-999-0000        11  2021-11-25         115.0
# 21    654 Pine St  888-999-0000        11  2021-11-25         115.0
# 22   321 Maple St  111-222-3333        12  2021-12-30         160.0
# 23   321 Maple St  111-222-3333        12  2021-12-30         160.0
# 24   789 Cedar St  444-555-6666        13  2022-01-05          85.0
# 25   789 Cedar St  444-555-6666        13  2022-01-05          85.0
# 26   234 Birch St  777-888-9999        14  2022-02-10         130.0
# 27   234 Birch St  777-888-9999        14  2022-02-10         130.0
# 28  876 Walnut St  222-333-4444        15  2022-03-15          75.0
# 29  876 Walnut St  222-333-4444        15  2022-03-15          75.0
#
#     order_item_id  product_id  quantity  unit_price           product_name  \
# 0               1           1         2        50.0           Smartphone X
# 1               2           2         1        25.0    Wireless Headphones
# 2               3           3         3        30.0             Laptop Pro
# 3               4           4         1        15.0               Smart TV
# 4               5           5         2        20.0          Running Shoes
# 5               6           6         1        10.0         Designer Dress
# 6               7           7         3        35.0           Coffee Maker
# 7               8           8         1        40.0           Toaster Oven
# 8               9           9         2        30.0          Action Camera
# 9              10          10         1        25.0  Board Game Collection
# 10             11          11         3        20.0               Yoga Mat
# 11             12          12         1        15.0           Skincare Set
# 12             13          13         2        25.0   Vitamin C Supplement
# 13             14          14         1        30.0       Weighted Blanket
# 14             15          15         3        40.0          Mountain Bike
# 15             16          16         1        35.0          Tennis Racket
# 16             17          17         2        15.0                    NaN
# 17             18          18         1        10.0                    NaN
# 18             19          19         3        30.0                    NaN
# 19             20          20         1        25.0                    NaN
# 20             21          21         2        20.0                    NaN
# 21             22          22         1        15.0                    NaN
# 22             23          23         3        25.0                    NaN
# 23             24          24         1        30.0                    NaN
# 24             25          25         2        40.0                    NaN
# 25             26          26         1        35.0                    NaN
# 26             27          27         3        15.0                    NaN
# 27             28          28         1        10.0                    NaN
# 28             29          29         2        30.0                    NaN
# 29             30          30         1        25.0                    NaN
#
#                                           description   price  category_id  \
# 0   The Smartphone X is a powerful and feature-ric...   500.0          1.0
# 1   Experience the freedom of wireless audio with ...   150.0          1.0
# 2   The Laptop Pro is a sleek and powerful device ...  1200.0          2.0
# 3   Transform your living room into an entertainme...   800.0          2.0
# 4   Get ready to hit the road with these lightweig...   100.0          3.0
# 5   Make a statement with this elegant designer dress   300.0          3.0
# 6   Start your day with a perfect cup of coffee br...    80.0          4.0
# 7   Upgrade your kitchen with this versatile toast...    70.0          4.0
# 8   Capture your adventures in stunning detail wit...   200.0          5.0
# 9   Enjoy hours of fun with this diverse collectio...    50.0          5.0
# 10  Enhance your yoga practice with this premium y...    30.0          6.0
# 11  Pamper your skin with this luxurious skincare ...   150.0          6.0
# 12  Boost your immune system and promote overall h...    20.0          7.0
# 13  Experience deep relaxation and improved sleep ...   100.0          7.0
# 14  Conquer the trails with this high-performance ...  1000.0          8.0
# 15  Take your tennis game to the next level with t...    54.0          8.0
# 16                                                NaN     NaN          NaN
# 17                                                NaN     NaN          NaN
# 18                                                NaN     NaN          NaN
# 19                                                NaN     NaN          NaN
# 20                                                NaN     NaN          NaN
# 21                                                NaN     NaN          NaN
# 22                                                NaN     NaN          NaN
# 23                                                NaN     NaN          NaN
# 24                                                NaN     NaN          NaN
# 25                                                NaN     NaN          NaN
# 26                                                NaN     NaN          NaN
# 27                                                NaN     NaN          NaN
# 28                                                NaN     NaN          NaN
# 29                                                NaN     NaN          NaN
#
#              category_name
# 0              Electronics
# 1              Electronics
# 2                    Books
# 3                    Books
# 4                 Clothing
# 5                 Clothing
# 6           Home & Kitchen
# 7           Home & Kitchen
# 8             Toys & Games
# 9             Toys & Games
# 10  Beauty & Personal Care
# 11  Beauty & Personal Care
# 12      Health & Household
# 13      Health & Household
# 14       Sports & Outdoors
# 15       Sports & Outdoors
# 16                     NaN
# 17                     NaN
# 18                     NaN
# 19                     NaN
# 20                     NaN
# 21                     NaN
# 22                     NaN
# 23                     NaN
# 24                     NaN
# 25                     NaN
# 26                     NaN
# 27                     NaN
# 28                     NaN
# 29                     NaN

# %%
t2_p6 = '''
SELECT 
  uid as user_id, uname as username
FROM
(
  SELECT
      u.user_id as uid, u.username as uname, COUNT(DISTINCT c.category_id) as user_categories
  FROM
    users u
  INNER JOIN orders o ON u.user_id = o.user_id
  LEFT JOIN order_items oi ON o.order_id = oi.order_id
  LEFT JOIN products p ON oi.product_id = p.product_id
  LEFT JOIN category c ON p.category_id = c.category_id
  GROUP BY
    uid, uname
)
WHERE user_categories = (
  SELECT COUNT(category_id) FROM category  
)
'''
ps.sqldf(t2_p6, locals())
# Out:
# Empty DataFrame
# Columns: [user_id, username]
# Index: []

# %%
# products.merge(reviews, how='right', on='product_id').groupby('product_id').agg({'rating': 'mean'}).reset_index().rename(columns={'rating': 'avg_rating'}).sort_values('product_id', ascending=True)

# %%
t2_p7 = '''
SELECT product_id, product_name
FROM
products
WHERE
product_id NOT IN (
    SELECT product_id
    FROM
    reviews
)
'''
ps.sqldf(t2_p7, locals())
# Out:
# Empty DataFrame
# Columns: [product_id, product_name]
# Index: []

# %%
t2_p8 = '''
SELECT DISTINCT u.user_id, u.username
FROM users u
INNER JOIN
(
    SELECT
        user_id,
        order_date,
        LAG(order_date) OVER (PARTITION BY user_id ORDER BY order_date) AS prev_order_date
    FROM
        orders
) o ON u.user_id = o.user_id
WHERE JULIANDAY(o.order_date) - JULIANDAY(o.prev_order_date) = 1
'''
ps.sqldf(t2_p8, locals())
# Out:
# Empty DataFrame
# Columns: [user_id, username]
# Index: []

# %%
t3_p9 = '''
SELECT
    c.category_id, c.category_name, SUM(oi.quantity * oi.unit_price) as total_sales_amount
FROM
order_items oi
LEFT JOIN products p ON oi.product_id = p.product_id
LEFT JOIN category c ON p.category_id = c.category_id
GROUP BY
c.category_id, c.category_name
ORDER BY
total_sales_amount DESC
LIMIT 3
'''
ps.sqldf(t3_p9, locals())
# Out:
#    category_id      category_name  total_sales_amount
# 0          NaN               None               570.0
# 1          8.0  Sports & Outdoors               155.0
# 2          4.0     Home & Kitchen               145.0

# %%
t3_p10 = '''
SELECT u.user_id, u.username
FROM
users u
INNER JOIN orders o ON u.user_id = o.user_id
LEFT JOIN order_items oi ON oi.order_id = o.order_id
LEFT JOIN products p ON oi.product_id = p.product_id
LEFT JOIN category c ON p.category_id = c.category_id
WHERE p.category_id = (
    SELECT category_id FROM category WHERE category_name = 'Toys & Games'
)
GROUP BY u.user_id, u.username
HAVING COUNT(DISTINCT oi.product_id) = (
    SELECT COUNT(product_id) FROM products WHERE category_id = (
        SELECT category_id FROM category WHERE category_name = 'Toys & Games'
    )
)
'''
ps.sqldf(t3_p10, locals())
# Out:
#    user_id     username
# 0        5  sarahwilson

# %%
t3_p11 = '''
SELECT 
    product_id, product_name, category_id, price 
FROM (
    SELECT 
        category_id, price, product_id, product_name,
        RANK() OVER (PARTITION BY category_id ORDER BY price DESC) AS rank
    FROM
        products
)
WHERE rank = 1
'''
ps.sqldf(t3_p11, locals())
# Out:
#    product_id      product_name  category_id   price
# 0           1      Smartphone X            1   500.0
# 1           3        Laptop Pro            2  1200.0
# 2           6    Designer Dress            3   300.0
# 3           7      Coffee Maker            4    80.0
# 4           9     Action Camera            5   200.0
# 5          12      Skincare Set            6   150.0
# 6          14  Weighted Blanket            7   100.0
# 7          15     Mountain Bike            8  1000.0

# %%
t3_p12 = '''
SELECT DISTINCT u.user_id, u.username
FROM users u
INNER JOIN
(
    SELECT
        user_id,
        order_date,
        LAG(order_date, 1) OVER (PARTITION BY user_id ORDER BY order_date) AS one_order_back,
        LAG(order_date, 2) OVER (PARTITION BY user_id ORDER BY order_date) AS two_order_back
    FROM
        orders
) o ON u.user_id = o.user_id
WHERE JULIANDAY(o.order_date) - JULIANDAY(o.one_order_back) = 1
AND JULIANDAY(o.one_order_back) - JULIANDAY(o.two_order_back) = 1
'''
ps.sqldf(t3_p12, locals())
# Out:
# Empty DataFrame
# Columns: [user_id, username]
# Index: []
